# %%
import pandas as pd

# %% [markdown]
# ## Read data from files

# %%
# import gene expression data from csv file
gene_expr = pd.read_csv("Example2_gene_expr.csv", index_col=0)

# %%
# import raw count data (high sequencing depth) from csv file
raw_count_high = pd.read_csv("Example2_raw_count_high.csv", index_col=0)

# %%
# import raw count data (medium sequencing depth) from csv file
raw_count_med = pd.read_csv("Example2_raw_count_med.csv", index_col=0)

# %%
# import raw count data (low sequencing depth) from csv file
raw_count_low = pd.read_csv("Example2_raw_count_low.csv", index_col=0)

# %%
# check imported gene expression levels
gene_expr
# Out:
#         condition_high_cell1  condition_high_cell2  condition_high_cell3  \
# Gene_1                   124                    81                    86
# Gene_2                    19                    52                    21
# Gene_3                    18                    16                    19
# Gene_4                    19                    24                    13
# Gene_5                     7                    28                     7
# Gene_6                     6                     4                     6
# Gene_7                     0                    28                    13
# Gene_8                     0                     0                     0
#
#         condition_high_cell4  condition_high_cell5  condition_high_cell6  \
# Gene_1                    55                    87                   107
# Gene_2                    48                    32                    40
# Gene_3                    17                    14                    17
# ...

# %%
# check imported raw counts (high sequencing depth)
raw_count_high
# Out:
#         condition_high_cell1  condition_high_cell2  condition_high_cell3  \
# Gene_1                    99                    45                    69
# Gene_2                    13                    44                    25
# Gene_3                    13                     8                    13
# Gene_4                    10                    14                    10
# Gene_5                     8                    17                    10
# Gene_6                     7                     5                     4
# Gene_7                     0                    17                    19
# Gene_8                     0                     0                     0
#
#         condition_high_cell4  condition_high_cell5  condition_high_cell6  \
# Gene_1                    66                    84                    87
# Gene_2                    52                    31                    31
# Gene_3                    17                    14                    17
# ...

# %%
# check imported raw counts (medium sequencing depth)
raw_count_med
# Out:
#         condition_med_cell1  condition_med_cell2  condition_med_cell3  \
# Gene_1                   34                   23                   25
# Gene_2                    5                    9                    4
# Gene_3                    4                    2                    7
# Gene_4                    3                    4                    5
# Gene_5                    3                    5                    1
# Gene_6                    1                    3                    3
# Gene_7                    0                    4                    5
# Gene_8                    0                    0                    0
#
#         condition_med_cell4  condition_med_cell5  condition_med_cell6  \
# Gene_1                   19                   30                   27
# Gene_2                   20                    9                   12
# Gene_3                    5                    3                    4
# ...

# %%
# check imported raw counts (low sequencing depth)
raw_count_low
# Out:
#         condition_low_cell1  condition_low_cell2  condition_low_cell3  \
# Gene_1                   12                    7                    8
# Gene_2                    4                    7                    5
# Gene_3                    3                    1                    6
# Gene_4                    0                    0                    1
# Gene_5                    0                    1                    0
# Gene_6                    1                    0                    0
# Gene_7                    0                    4                    0
# Gene_8                    0                    0                    0
#
#         condition_low_cell4  condition_low_cell5  condition_low_cell6  \
# Gene_1                    8                   14                   11
# Gene_2                    6                    1                    5
# Gene_3                    1                    2                    3
# ...

# %% [markdown]
# ## Histrograms

# %%
# plot histrogram of gene expression (blue)
gene_expr.T.hist(figsize=(24,2), layout=(1,8), color="blue");
# plot histrogram of raw counts (high sequencing depth)
raw_count_high.T.hist(figsize=(24,2), layout=(1,8), color="red");
# plot histrogram of raw counts (mediun sequencing depth)
raw_count_med.T.hist(figsize=(24,2), layout=(1,8), color="orange");
# plot histrogram of raw counts (low sequencing depth)
raw_count_low.T.hist(figsize=(24,2), layout=(1,8), color="yellow");

# %% [markdown]
# ## Sparsity

# %%
# sparsity of simulated gene expression level
100 * sum((gene_expr == 0).sum()) / gene_expr.size
# Out:
# 20.333333333333332

# %%
# sparsity of simulated raw count with high sequencing depth
100 * sum((raw_count_high == 0).sum()) / raw_count_high.size
# Out:
# 21.666666666666668

# %%
# sparsity of simulated raw count with medium sequencing depth
100 * sum((raw_count_med == 0).sum()) / raw_count_med.size
# Out:
# 28.458333333333332

# %%
# sparsity of simulated raw count with low sequencing depth
100 * sum((raw_count_low == 0).sum()) / raw_count_low.size
# Out:
# 39.875
